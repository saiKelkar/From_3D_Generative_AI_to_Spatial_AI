# %% [markdown]
# <a href="https://colab.research.google.com/github/saiKelkar/From_3D_Generative_AI_to_Spatial_AI/blob/main/3d_generative_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/openai/shap-e
# Out:
# Cloning into 'shap-e'...
# remote: Enumerating objects: 336, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 336 (delta 35), reused 13 (delta 13), pack-reused 281 (from 2)
# Receiving objects: 100% (336/336), 11.72 MiB | 13.40 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
# %cd shap-e
# !pip install -e .
# Out:
# /content/shap-e
# Obtaining file:///content/shap-e
#   Preparing metadata (setup.py) ... done
# Collecting clip@ git+https://github.com/openai/CLIP.git (from shap-e==0.0.0)
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-fiu9_jwq/clip_78264df914444ae2a013712391e20fca
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-fiu9_jwq/clip_78264df914444ae2a013712391e20fca
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (3.32.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (11.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (2.11.0+cpu)
# Collecting fire (from shap-e==0.0.0)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: humanize in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (4.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (3.10.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (2.1.3)
# Requirement already satisfied: blobfile in /usr/local/lib/python3.13/dist-packages (from shap-e==0.0.0) (3.3.0)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.13/dist-packages (from blobfile->shap-e==0.0.0) (3.23.0)
# Requirement already satisfied: urllib3>=2 in /usr/local/lib/python3.13/dist-packages (from blobfile->shap-e==0.0.0) (2.5.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.13/dist-packages (from blobfile->shap-e==0.0.0) (6.1.2)
# Collecting ftfy (from clip@ git+https://github.com/openai/CLIP.git->shap-e==0.0.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from clip@ git+https://github.com/openai/CLIP.git->shap-e==0.0.0) (26.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from clip@ git+https://github.com/openai/CLIP.git->shap-e==0.0.0) (2025.11.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from clip@ git+https://github.com/openai/CLIP.git->shap-e==0.0.0) (0.26.0+cpu)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.13/dist-packages (from fire->shap-e==0.0.0) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->shap-e==0.0.0) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->shap-e==0.0.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->shap-e==0.0.0) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->shap-e==0.0.0) (2026.7.22)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.13/dist-packages (from scikit-image->shap-e==0.0.0) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.13/dist-packages (from scikit-image->shap-e==0.0.0) (2.37.4)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.13/dist-packages (from scikit-image->shap-e==0.0.0) (2026.8.23)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.13/dist-packages (from scikit-image->shap-e==0.0.0) (0.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->shap-e==0.0.0) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->shap-e==0.0.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->shap-e==0.0.0) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->shap-e==0.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->shap-e==0.0.0) (2025.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->shap-e==0.0.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->shap-e==0.0.0) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.13/dist-packages (from ftfy->clip@ git+https://github.com/openai/CLIP.git->shap-e==0.0.0) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->shap-e==0.0.0) (3.0.3)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 4.8 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369549 sha256=5a8e094b579341925b266104b888a90787403862358b7dad3a6caf0fbde5af8d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ly1mywe0/wheels/cb/a8/74/5f32d6cf0407457f0f62737b6da5c14eb86b9cac476fdf630d
# Successfully built clip
# Installing collected packages: ftfy, fire, clip, shap-e
#   Running setup.py develop for shap-e
# Successfully installed clip-1.0 fire-0.7.1 ftfy-6.3.1 shap-e-0.0.0

# %%
import torch

from shap_e.diffusion.sample import sample_latents
from shap_e.diffusion.gaussian_diffusion import diffusion_from_config
from shap_e.models.download import load_model, load_config
from shap_e.util.notebooks import create_pan_cameras, decode_latent_images

# %%
# Instantiate the encoder and latent diffusion model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

xm = load_model('transmitter', device=device)
model = load_model('text300M', device=device)
diffusion = diffusion_from_config(load_config('diffusion'))
# Out:
# /content/shap-e/shap_e/models/nn/checkpoint.py:31: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/shap-e/shap_e/models/nn/checkpoint.py:43: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/shap-e/shap_e/models/nn/checkpoint.py:61: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/shap-e/shap_e/models/nn/checkpoint.py:86: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
#   0%|          | 0.00/1.78G [00:00<?, ?iB/s]
# 100%|███████████████████████████████████████| 890M/890M [00:14<00:00, 64.9MiB/s]
#   0%|          | 0.00/1.26G [00:00<?, ?iB/s]

# %%
# Defining hyperparameters

batch_size = 4
guidance_scale = 15.0
prompt = "a big boat"

latents = sample_latents(
    batch_size = batch_size,
    model = model,
    diffusion = diffusion,
    guidance_scale = guidance_scale,
    model_kwargs = dict(texts = [prompt] * batch_size),
    progress = True,
    clip_denoised = True,
    use_fp16 = True,
    use_karras = True,
    karras_steps = 64,
    sigma_min = 1e-3,
    sigma_max = 160,
    s_churn = 0
)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
# Saving the generated latent as single .ply file

from shap_e.util.notebooks import decode_latent_mesh

for i, latent in enumerate(latents):
  with open(f'example_mesh_{i}.ply', 'wb') as f:
    decode_latent_mesh(xm, latent).tri_mesh().write_ply(f)
